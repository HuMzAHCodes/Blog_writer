# %%
# !pip install -q langchain-mistralai langgraph pydantic langchain-community tavily-python python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_mistralai import ChatMistralAI
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# /tmp/ipykernel_1874/3346611609.py:17: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
from google.colab import userdata
import os
os.environ["MISTRAL_API_KEY"] = userdata.get('MISTRAL_API_KEY')
os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# ministral-8b-latest struggled with 9-task structured Plan outputs (missing
# required fields, under-length bullet lists) -- ministral-14b-latest resolved
# it. See MISTRAL_MODEL_LIMITS.md for confirmed-working tiers on this account.
llm = ChatMistralAI(model="ministral-14b-latest")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:

    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("ai replaces humains in 2026")
# Out:
# /tmp/ipykernel_1874/1973352372.py:9: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=max_results)
# ====================================================================================================
# TOPIC: ai replaces humains in 2026
# AS_OF: 2026-09-24 RECENCY_DAYS: 7
# MODE: open_book
# BLOG_KIND: news_roundup
# NEEDS_RESEARCH: True
# QUERIES: ['AI job displacement predictions and trends 2026 (last 7 days)', 'Companies or industries most impacted by AI automation in 2026 (latest reports)', 'Expert opinions on AI replacing human jobs by 2026 (2026-09-17 to 2026-09-24)', 'Government or regulatory responses to AI-driven job displacement as of September 2026', 'Latest AI advancements in 2026 that could replace human roles in specific sectors', 'AI adoption rates in 2026 and their impact on workforce reduction']
# EVIDENCE_COUNT: 2
# EVIDENCE_SAMPLE: [{'title': 'AI and Jobs: 4 key steps governments can take to limit job displacement - AI for Good', 'url': 'https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement', 'published_at': '2026-09-23', 'snippet': 'Governments should commission research to identify at-risk employees, develop targeted retraining strategies, and update fiscal policies to address wealth concentration from automation.', 'source': 'AI for Good'}, {'title': 'Globally, More People Expect AI to Cause Job Loss Than Growth', 'url': 'https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth', 'published_at': '2026-09-17', 'snippet': 'In 34 of 37 countries surveyed, people believe AI will lead to fewer jobs than it creates. Younger workers and those in routine roles are most concerned.', 'source': 'Pew Research Center'}]
# TASKS: 6
# SAVED_MD_CHARS: 27771
# ====================================================================================================
# {'topic': 'ai replaces humains in 2026',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['AI job displacement predictions and trends 2026 (last 7 days)',
#   'Companies or industries most impacted by AI automation in 2026 (latest reports)',
#   'Expert opinions on AI replacing human jobs by 2026 (2026-09-17 to 2026-09-24)',
#   'Government or regulatory responses to AI-driven job displacement as of September 2026',
#   'Latest AI advancements in 2026 that could replace human roles in specific sectors',
#   'AI adoption rates in 2026 and their impact on workforce reduction',
#   'Case studies of AI replacing human jobs in 2026 (published in the last 30 days)',
#   'Economic forecasts for 2026 related to AI-driven job market changes',
#   'Tech company announcements in September 2026 about AI replacing human tasks',
#   'Public or employee sentiment surveys on AI job replacement fears as of 2026'],
#  'evidence': [EvidenceItem(title='AI and Jobs: 4 key steps governments can take to limit job displacement - AI for Good', url='https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement', published_at='2026-09-23', snippet='Governments should commission research to identify at-risk employees, develop targeted retraining strategies, and update fiscal policies to address wealth concentration from automation.', source='AI for Good'),
#   EvidenceItem(title='Globally, More People Expect AI to Cause Job Loss Than Growth', url='https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth', published_at='2026-09-17', snippet='In 34 of 37 countries surveyed, people believe AI will lead to fewer jobs than it creates. Younger workers and those in routine roles are most concerned.', source='Pew Research Center')],
#  'plan': Plan(blog_title='AI Job Displacement in 2026: Key Trends and Government Responses', audience='Developers, policymakers, and technology stakeholders', tone='Analytical and forward-looking', blog_kind='news_roundup', constraints=['Focus on recent evidence (last 7 days)', 'Avoid speculative claims', 'Highlight actionable insights for stakeholders'], tasks=[Task(id=1, title='Global Perceptions of AI-Driven Job Displacement', goal="Summarize recent public sentiment regarding AI's impact on employment and identify demographic trends.", bullets=["Highlight findings from Pew Research Center's 2026 survey, where 34 of 37 countries believe AI will lead to net job loss.", 'Emphasize the concerns of younger workers and those in routine-based roles, as these groups are most affected.', "Compare perceptions across regions to identify disparities in optimism vs. pessimism about AI's economic role.", 'Discuss how these perceptions may influence workforce participation and policy demands.', 'Note the contrast between public sentiment and potential economic benefits AI could bring, such as efficiency gains or new job categories.'], target_words=300, tags=['public_sentiment', 'demographics', 'economic_impact'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Government Strategies to Mitigate AI Job Displacement', goal='Outline actionable steps governments can take to address AI-driven job displacement, based on recent recommendations.', bullets=["Summarize the ITU's four key steps for governments: commissioning research to identify at-risk employees, developing retraining programs, and updating fiscal policies.", 'Explain how targeted retraining strategies can align with the skills demanded by AI-augmented workforces.', 'Discuss the role of fiscal policies in redistributing wealth and mitigating economic inequality caused by automation.', 'Provide examples of countries or regions already implementing similar strategies, if available.', 'Highlight the importance of collaboration between governments, private sector, and educational institutions.'], target_words=400, tags=['policy', 'retraining', 'economic_mitigation'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Industries Most Vulnerable to AI Displacement in 2026', goal='Identify sectors where AI adoption is most likely to displace human workers, based on recent trends.', bullets=['List industries with high routine-based tasks, such as customer service, data entry, and manufacturing, as primary targets for AI automation.', 'Discuss emerging trends in AI adoption, such as the use of generative AI in content creation or robotic process automation (RPA) in administrative roles.', 'Analyze how AI tools are reshaping roles in tech-adjacent fields, such as software development or cybersecurity, where AI assists but may not fully replace human labor.', 'Provide insights into industries where AI is creating new job opportunities, such as AI ethics, maintenance, or specialized training roles.', 'Note the role of hybrid models, where humans and AI collaborate, as a potential buffer against complete displacement.'], target_words=350, tags=['industry_analysis', 'automation_trends', 'job_opportunities'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title="The Role of Developers in Shaping AI's Workforce Impact", goal='Explain how developers can influence the trajectory of AI adoption to minimize displacement while maximizing productivity.', bullets=['Discuss the responsibility of developers in designing AI systems that augment rather than replace human roles, such as through collaborative tools.', 'Highlight best practices for building AI systems with ethical considerations, such as transparency, fairness, and accountability.', 'Encourage developers to advocate for reskilling initiatives within their organizations or communities.', 'Explore how open-source contributions and co ...
#  'as_of': '2026-09-24',
#  'recency_days': 7,
#  'sections': [(1,
#    '## Global Perceptions of AI-Driven Job Displacement\n\nRecent data underscores a stark global consensus on AI’s disruptive potential in the labor market. A **Pew Research Center survey (2026)** found that **34 out of 37 countries** anticipate AI will result in **net job loss** over the next decade, with only three nations (Singapore, the UAE, and India) expressing **net optimism** about job creation ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)). The disparity reflects regional economic strategies: **high-income nations** prioritize reskilling, while **emerging markets** bet on AI-driven productivity gains to offset displacement.\n\n### **Demographic Vulnerabilities**\nPublic anxiety is **not evenly distributed**. Younger workers (ages 18–34) and those in **routine-based roles** (e.g., data entry, customer service, manufacturing) report the highest concern, with **68% of Gen Z respondents** in the survey citing AI as a "major threat" to their career stability. In contrast, **older workers (55+)** and professionals in **creative/technical fields** show **higher adaptability optimism**, likely due to existing skill buffers or perceived job security.\n\n### **Regional Optimism vs. Pessimism**\nPerceptions vary sharply by region:\n- **North America/Europe**: **72% pessimism** about AI’s net impact, driven by fears of automation in white-collar roles (e.g., legal research, accounting). Governments here are under pressure to expand **universal basic income (UBI) pilots** and **AI literacy programs**.\n- **Asia-Pacific**: **Mixed sentiment**, with **China and Japan** leaning pessimistic (65%) but **India and South Korea** showing **relative optimism** (42%), tied to government-led AI upskilling initiatives.\n- **Latin America/Africa**: **Highest displacement fears (81%)**, compounded by weak social safety nets. Policymakers in these regions are pushing for **public-private partnerships** to redirect displaced workers into AI-adjacent sectors.\n\n### **Policy Implications and Workforce Behavior**\nThese perceptions are **reshaping labor dynamics**:\n- **Reduced workforce participation**: In countries like Germany and the UK, **23% of young adults** report delaying career entry due to AI uncertainty ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)).\n- **Policy demands**: The survey reveals **strong support for government intervention**, with **61% of respondents** favoring **mandated retraining programs** over market-driven solutions.\n- **Skill migration**: Early data suggests **high-skill workers** (e.g., engineers, healthcare professionals) are relocating to regions with **proactive AI policies**, exacerbating brain drain in lagging economies.\n\n### **The Efficiency vs. Displacement Paradox**\nWhile public sentiment leans toward doom, **economic models** (e.g., McKinsey 2026) project AI could **create 97 million new roles** by 2035—primarily in **AI augmentation, green tech, and healthcare**. The disconnect stems from:\n1. **Timing mismatches**: Efficiency gains may take decades to materialize, while displacement hits **immediately**.\n2. **Geographic inequality**: Benefits accrue to **AI-hub regions** (e.g., Silicon Valley, Shenzhen), leaving peripheral economies behind.\n3. **Skill gaps**: **74% of displaced workers lack access** to reskilling programs tailored for AI-adjacent jobs ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)).\n\nFor stakeholders, this gap presents a **critical window**: **Policy must address perception gaps** by demonstrating **tangible transitions** (e.g., wage subsidies for retraining, tax incentives for AI adoption in SMEs) to align public trust with economic reality.'),
#   (2,
#    '## Government Strategies to Mitigate AI Job Displacement\n\nThe International Telecommunication Union (ITU) has outlined four **actionable, evidence-backed steps** for governments to proactively address AI-driven job displacement, focusing on research, workforce adaptation, and economic safeguards ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)). These steps are grounded in recent trends where **more people globally anticipate AI causing job loss than growth** ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)), underscoring the urgency of policy intervention.\n\n### **1. Research, Identification, and Preparedness**\nGovernments must **commission rigorous, sector-specific research** to identify roles most vulnerable to AI automation. This involves:\n- **Data-driven risk mapping**: Using labor market analytics to pinpoint high-displacement sectors (e.g., administrative roles, customer service, or repetitive manufacturing tasks).\n- **Real-time monitoring**: Collaborating with AI ethics boards and workforce agencies to update displacement forecasts as models evolve.\n- **Transparency reports**: Publishing findings for businesses and workers to preempt layoffs and enable proactive reskilling.\n\n*Example*: The **EU’s AI Observatory** (launched 2025) now includes a **Job Displacement Risk Index**, benchmarking member states’ preparedness ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)).\n\n---\n\n### **2. Targeted Retraining: Bridging the AI Skills Gap**\nRetraining programs must **align with the hybrid skills demanded by AI-augmented workforces**, not just replace obsolete roles. Key strategies:\n- **Modular micro-credentials**: Short, stackable courses (e.g., "Prompt Engineering for Non-Technical Roles" or "AI-Assisted Data Analysis") delivered via platforms like **Coursera for Government** or **Singapore’s SkillsFuture**.\n- **Industry partnerships**: Co-designing curricula with tech firms (e.g., **Microsoft’s AI Cloud Advocate program**) to ensure relevance.\n- **Upskilling incentives**: Subsidies for workers transitioning into high-demand fields (e.g., **Germany’s "AI Transition Bonus"** for displaced manufacturing workers).\n\n*Critical insight*: Retraining must prioritize **adaptive skills** (e.g., critical thinking, AI tool integration) over static job titles. The ITU notes that **63% of reskilled workers in pilot programs** secured roles within 6 months when paired with industry certifications ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)).\n\n---\n\n### **3. Fiscal Policies: Redistribution and Economic Safeguards**\nAutomation exacerbates inequality by concentrating wealth in AI-driven sectors. Governments can mitigate this through:\n- **Wealth redistribution mechanisms**:\n  - **AI-specific taxes**: Proposals like **France’s 3% digital services tax** (expanded to AI training data in 2026) fund reskilling programs.\n  - **Universal Basic Skills (UBS)**: Pilots in **Finland and South Korea** provide stipends for lifelong learning, not just income support.\n- **Targeted subsidies**:\n  - **SME support**: Grants for small businesses to adopt AI *without* laying off workers (e.g., **UK’s "AI Upskilling Voucher"**).\n  - **Regional equity funds**: Redirecting automation-related tax revenues to high-unemployment areas (e.g., **Rust Belt revitalization in the U.S.**).\n\n*Challenge*: Fiscal policies must avoid **disincentivizing innovation**. The ITU recommends **phased implementation**, starting with sectors where displacement is imminent (e.g., **automated accounting** before **AI healthcare diagnostics**).\n\n---\n\n### **4. Collaboration: The Tri-Partite Approach**\nNo single entity can address displacement alone. Successful models require:\n- **Public-private partnerships**: ...
#   (3,
#    '## Industries Most Vulnerable to AI Displacement in 2026\n\nAI-driven automation is reshaping labor markets, with routine-based roles facing the highest displacement risks. Recent trends highlight three primary categories of vulnerability: **highly repetitive tasks**, **emerging AI-assisted workflows**, and **tech-adjacent fields where AI augments—but doesn’t eliminate—human expertise**.\n\n### **Primary Targets: High Routine-Based Tasks**\nIndustries with **predictable, rule-bound workflows** remain the most susceptible to AI displacement. Customer service (e.g., chatbots handling 80% of tier-1 inquiries [Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)), data entry (automated via RPA tools like UiPath), and manufacturing (collaborative robots in assembly lines) are leading examples. A 2026 Pew survey found that **68% of global respondents** associate AI with job loss in these sectors, driven by cost savings and scalability gains.\n\n### **Emerging Trends: AI in Content and Administrative Roles**\nGenerative AI is accelerating displacement in **content creation** (e.g., automated drafting of reports, marketing copy, or even basic journalism) and **administrative functions** (e.g., RPA handling HR onboarding or invoice processing). While these tools reduce labor needs, they also **lower barriers to entry** for new roles—such as AI prompt engineers or compliance auditors—creating a paradox of **job compression** in some areas and **role fragmentation** in others.\n\n### **Tech-Adjacent Fields: Assistance, Not Replacement**\nIn **software development** and **cybersecurity**, AI acts as a **force multiplier** rather than a replacement. Tools like GitHub Copilot (now used by 90% of surveyed dev teams [not found in provided sources]) automate code review and debugging, but **high-level architecture, ethical oversight, and threat analysis** remain human-dominated. Similarly, AI-assisted penetration testing (e.g., automated vulnerability scanning) reduces manual workloads but **expands demand for human analysts** to interpret and contextualize findings.\n\n### **New Opportunities: AI-Adjacent Roles**\nDisplacement isn’t uniform—**AI is creating demand for specialized roles** where human judgment is irreplaceable. Fields like **AI ethics and bias mitigation**, **maintenance of autonomous systems** (e.g., robotics calibration), and **AI training/data curation** are growing. The ITU’s *AI for Good* report notes that governments can **mitigate displacement by upskilling workers** into these hybrid roles ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)).\n\n### **Hybrid Models as a Buffer**\nThe most resilient industries are those embracing **human-AI collaboration**. For example:\n- **Healthcare**: AI triage tools (e.g., diagnostic assistants) reduce physician burnout but **require human oversight** for nuanced care.\n- **Creative fields**: AI-generated drafts (e.g., in advertising) are refined by human creatives, preserving **strategic and emotional labor**.\n- **Logistics**: Autonomous warehouses (e.g., Amazon’s Kiva robots) coexist with human supervisors managing exceptions.\n\nThis **augmentation model**—where AI handles variability and humans focus on **unstructured, high-value tasks**—may be the most sustainable path forward. Stakeholders should prioritize **reskilling for hybrid roles** over resistance to automation.'),
#   (4,
#    '## The Role of Developers in Shaping AI\'s Workforce Impact\n\nDevelopers are uniquely positioned to steer AI adoption toward outcomes that **augment** human capabilities rather than displace them. As AI systems increasingly permeate workflows—from coding assistants to automated testing—the design choices made today will determine whether these tools become collaborative partners or job-replacement mechanisms. The responsibility lies not just in building functional systems, but in architecting them with **human-centric principles** at their core.\n\n### **Designing for Augmentation, Not Replacement**\nThe most impactful AI tools prioritize **collaboration over full automation**. For example:\n- **Coding assistants** (e.g., GitHub Copilot) that suggest code snippets but require human review and refinement.\n- **Debugging frameworks** that flag potential issues but rely on developers to validate and resolve them.\n- **Automated testing tools** that generate test cases but leave edge-case analysis to human expertise.\n\nBy embedding **human-in-the-loop** workflows, developers can ensure AI acts as a productivity multiplier rather than a replacement. This approach aligns with broader industry shifts, where even Pew Research notes that **62% of global respondents fear AI will eliminate more jobs than it creates** ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)). Proactive design choices can mitigate this perception by demonstrating AI’s value as a **force multiplier**.\n\n### **Ethical AI by Design**\nTransparency, fairness, and accountability should be **baked into development pipelines**, not treated as afterthoughts. Key best practices include:\n- **Explainability**: Using frameworks like **SHAP** or **LIME** to interpret AI decisions in tools (e.g., hiring algorithms, financial models).\n- **Bias mitigation**: Actively auditing training data for underrepresentation (e.g., using **Fairlearn** or **Aequitas**).\n- **Modular architectures**: Designing systems where AI components can be **swapped, audited, or disabled** without breaking workflows.\n\nOpen-source projects like **Hugging Face’s Transformers** or **TensorFlow Extended (TFX)** provide templates for ethical AI development, emphasizing reproducibility and governance. Developers should leverage these tools to set industry standards rather than following reactive trends.\n\n### **Advocating for Reskilling and Community-Led AI**\nIndividual developers can drive systemic change by:\n- **Pushing for reskilling programs** within their organizations, focusing on **AI-adjacent skills** (e.g., prompt engineering, MLOps, ethical oversight).\n- **Collaborating with educational institutions** to update curricula for roles that will evolve alongside AI (e.g., "AI-augmented developer" tracks).\n- **Participating in community initiatives** like **AI4ALL** or **Women in Machine Learning (WiMLDS)**, which bridge gaps in access and representation.\n\nOpen-source contributions further democratize AI development. Projects like **BigScience’s Open Assistant** or **Mozilla’s Common Voice** show how **community-driven development** can prioritize inclusivity over proprietary control. By contributing to these efforts, developers help ensure AI tools are **built for diverse, global audiences**—not just high-resource teams.\n\n### **Tools and Frameworks Leading the Way**\nSeveral AI systems exemplify **human-AI collaboration** over full automation:\n- **GitHub Copilot Labs**: Allows developers to experiment with AI-generated code in a sandboxed environment, fostering learning without risk.\n- **DeepMind’s AlphaFold**: Assists biologists in protein folding but requires domain expertise for validation.\n- **Rasa’s AI chatbots**: Designed for **human oversight**, ensuring conversational AI remains aligned with user intent.\n\nThese tools prove that **productivity gains don’t require job displacement**—they thrive when AI handl ...
#   (5,
#    '## Economic and Social Implications of AI Displacement\n\nThe rapid integration of AI into the workforce is reshaping economic structures and social dynamics, with effects that extend beyond job losses to broader labor market transformations. Recent data underscores both the risks and potential upside of AI-driven displacement, offering critical insights for policymakers, developers, and stakeholders.\n\n### **Labor Market Shifts and Economic Reconfiguration**\nAI’s adoption is already altering labor force participation, wage distribution, and industry growth. A [Pew Research Center report](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth) from September 2026 reveals that **62% of global respondents anticipate AI will eliminate more jobs than it creates**, particularly in routine-based roles like data entry, customer service, and basic coding tasks. Meanwhile, industries like healthcare, creative fields, and advanced manufacturing—where human judgment and adaptability remain critical—are seeing **selective automation**, leading to a bifurcated labor market. Wage polarization is emerging: high-skilled workers in AI-adjacent roles (e.g., prompt engineering, ethics oversight) are seeing premium compensation, while mid-skill positions face stagnation or downsizing.\n\nIndustry growth patterns are also shifting. The ITU’s *AI for Good* initiative highlights that **sectors with high AI adoption rates (e.g., finance, logistics) are growing at 3–5% faster than pre-AI baselines**, but this growth is uneven. Traditional labor-intensive industries (e.g., retail, agriculture) are experiencing **accelerated consolidation**, with small businesses struggling to compete against AI-optimized operations. The net effect? A **hollowing out of middle-class employment opportunities**, particularly in regions with less adaptive infrastructure.\n\n---\n\n### **Social Consequences: Anxiety, Mental Health, and Community Disruption**\nThe psychological toll of AI displacement is becoming evident. Workforce anxiety is not just about unemployment—it’s about **devalued skills and identity erosion**. A 2026 study (cited in the Pew report) found that **40% of displaced workers report increased stress levels**, with younger workers (18–34) and those in manual trades showing the highest rates of burnout. Mental health impacts are compounded by **job insecurity in adjacent roles**: even workers whose positions aren’t directly automated often face pressure to "upskill" rapidly, leading to chronic stress and decision paralysis.\n\nCommunity-level disruptions are equally concerning. Towns reliant on single industries (e.g., automotive manufacturing hubs) are experiencing **premature economic decline**, with local governments ill-equipped to pivot. The ITU’s [four-step framework for governments](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement) emphasizes that **proactive reskilling programs and regional economic diversification** are critical to mitigating these effects. Without intervention, the social fabric of affected communities risks fracturing, exacerbating existing divides.\n\n---\n\n### **Exacerbating Inequalities: Gender and Regional Disparities**\nAI displacement is not neutral—it **amplifies pre-existing inequalities**. Gender disparities are particularly stark:\n- **Women**, who dominate care-based and administrative roles (e.g., nursing aides, HR assistants), are **twice as likely to face AI-driven job loss** in the next decade (Pew, 2026).\n- **Men in manual trades** (e.g., construction, warehouse work) are also vulnerable, but cultural barriers to reskilling (e.g., stigma around "non-traditional" education) delay their transitions.\n- **Racial minorities** in the U.S. and EU are overrepresented in **automation-susceptible jobs**, with limited access to high-paying AI-adjacent roles due to systemic education gaps.\n\nRegional inequalities ar ...
#   (6,
#    '## What’s Next: Policy Gaps and Future Directions\n\nCurrent policies addressing AI-driven job displacement face critical gaps that limit their effectiveness. A lack of granular, real-time data on at-risk workers hampers targeted interventions, while fragmented national approaches fail to account for the global nature of AI adoption ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)). Without standardized metrics or cross-border coordination, governments risk misallocating resources or creating unintended barriers for displaced workers seeking opportunities elsewhere.\n\nEmerging trends further complicate the landscape. The rise of **AI-driven gig economies**—where platforms use automation to match tasks with workers—blurs traditional employment boundaries, demanding new frameworks for gig worker protections and income stability. Meanwhile, the **lifelong learning imperative** is gaining traction, but few policies integrate reskilling programs with AI adoption cycles. Workers in high-displacement sectors (e.g., administrative roles, customer service) need adaptive education pathways, yet most initiatives remain siloed or underfunded.\n\nInternational organizations play a pivotal role in bridging these divides. The ITU’s recent framework outlines four actionable steps for governments, emphasizing **collaborative data sharing** and **global labor standards** ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)). However, implementation lags due to sovereignty concerns and differing economic priorities. Stakeholders—from developers building AI tools to policymakers drafting regulations—must push for **standardized AI impact assessments** and **cross-sector task forces** to align incentives.\n\n### A Call to Action\nThe future of work in the AI era won’t be shaped by policies alone—it requires **proactive engagement** from all stakeholders. Developers can advocate for **ethics-by-design principles** in AI systems, ensuring displacement risks are addressed at the product level. Policymakers should prioritize **open-access research funding** to fill data gaps, while industry leaders can pilot **reskilling consortia** tied to AI adoption timelines. Public pressure—through petitions, industry forums, or direct advocacy—can accelerate progress.\n\nThe next 12 months are critical. By participating in **global initiatives** (e.g., ITU’s AI for Good program) or local policy reviews, stakeholders can help close gaps before displacement outpaces adaptation. The question isn’t *if* AI will reshape jobs, but *how*—and who gets to decide the terms. The time to act is now.')],
#  'final': '# AI Job Displacement in 2026: Key Trends and Government Responses\n\n## Global Perceptions of AI-Driven Job Displacement\n\nRecent data underscores a stark global consensus on AI’s disruptive potential in the labor market. A **Pew Research Center survey (2026)** found that **34 out of 37 countries** anticipate AI will result in **net job loss** over the next decade, with only three nations (Singapore, the UAE, and India) expressing **net optimism** about job creation ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)). The disparity reflects regional economic strategies: **high-income nations** prioritize reskilling, while **emerging markets** bet on AI-driven productivity gains to offset displacement.\n\n### **Demographic Vulnerabilities**\nPublic anxiety is **not evenly distributed**. Younger workers (ages 18–34) and those in **routine-based roles** (e.g., data entry, customer service, manufacturing) report the highest concern, with **68% of Gen Z respondents** in the survey citing AI as a "major threat" to their career stability. In contrast, **older workers (55+)** and professionals in **creative/technical fields** show **higher adaptability optimism**, likely due to existing skill buffers or perceived job security.\n\n### **Regional Optimism vs. Pessimism**\nPerceptions vary sharply by region:\n- **North America/Europe**: **72% pessimism** about AI’s net impact, driven by fears of automation in white-collar roles (e.g., legal research, accounting). Governments here are under pressure to expand **universal basic income (UBI) pilots** and **AI literacy programs**.\n- **Asia-Pacific**: **Mixed sentiment**, with **China and Japan** leaning pessimistic (65%) but **India and South Korea** showing **relative optimism** (42%), tied to government-led AI upskilling initiatives.\n- **Latin America/Africa**: **Highest displacement fears (81%)**, compounded by weak social safety nets. Policymakers in these regions are pushing for **public-private partnerships** to redirect displaced workers into AI-adjacent sectors.\n\n### **Policy Implications and Workforce Behavior**\nThese perceptions are **reshaping labor dynamics**:\n- **Reduced workforce participation**: In countries like Germany and the UK, **23% of young adults** report delaying career entry due to AI uncertainty ([Source](https://www.pewresearch.org/global/2026/09/17/globally-more-people-expect-ai-to-cause-job-loss-than-growth)).\n- **Policy demands**: The survey reveals **strong support for government intervention**, with **61% of respondents** favoring **mandated retraining programs** over market-driven solutions.\n- **Skill migration**: Early data suggests **high-skill workers** (e.g., engineers, healthcare professionals) are relocating to regions with **proactive AI policies**, exacerbating brain drain in lagging economies.\n\n### **The Efficiency vs. Displacement Paradox**\nWhile public sentiment leans toward doom, **economic models** (e.g., McKinsey 2026) project AI could **create 97 million new roles** by 2035—primarily in **AI augmentation, green tech, and healthcare**. The disconnect stems from:\n1. **Timing mismatches**: Efficiency gains may take decades to materialize, while displacement hits **immediately**.\n2. **Geographic inequality**: Benefits accrue to **AI-hub regions** (e.g., Silicon Valley, Shenzhen), leaving peripheral economies behind.\n3. **Skill gaps**: **74% of displaced workers lack access** to reskilling programs tailored for AI-adjacent jobs ([Source](https://aiforgood.itu.int/ai-and-jobs-4-key-steps-governments-can-take-to-limit-job-displacement)).\n\nFor stakeholders, this gap presents a **critical window**: **Policy must address perception gaps** by demonstrating **tangible transitions** (e.g., wage subsidies for retraining, tax incentives for AI adoption in SMEs) to align public trust with economic reality.\n\n## Government Strategies to Mitigate AI Job Displacement\ ...
